# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv')

# %%
train
# Out:
#                                        COMMENT_ID                AUTHOR  \
# 0     LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU             Julius NM
# 1             z13jhp0bxqncu512g22wvzkasxmvvzjaz04       ElNino Melendez
# 2             z13fwbwp1oujthgqj04chlngpvzmtt3r3dw                GsMega
# 3             z13lfzdo5vmdi1cm123te5uz2mqig1brz04        ferleck ferles
# 4             z12avveb4xqiirsix04chxviiljryduwxg0           BeBe Burkey
# ...                                           ...                   ...
# 1152  _2viQ_Qnc6_RKHVetk9kLzx8ZC62_J7y73FWFSBTe8Q           ThirdDegr3e
# 1153  _2viQ_Qnc68TufyXKiTwky80ewSPbhRiD5XFHrJH9lg      Ysobel Schofield
# 1154  _2viQ_Qnc6-pY-1yR6K2FhmC5i48-WuNx5CumlHLDAI  Sabina Pearson-Smith
# 1155  _2viQ_Qnc6_k_n_Bse9zVhJP8tJReZpo8uM2uZfnzDs         jeffrey jules
# 1156  _2viQ_Qnc6_yBt8UGMWyg3vh0PulTqcqyQtdE7d4Fl0        Aishlin Maciel
#
#                             DATE  \
# 0            2013-11-07T06:20:48
# 1            2013-11-09T08:28:43
# 2            2013-11-10T16:05:38
# 3            2013-11-27T21:39:24
# 4            2013-11-28T16:30:13
# ...                          ...
# 1152  2013-07-13T20:47:40.793000
# 1153  2013-07-13T20:17:25.181000
# 1154  2013-07-13T13:14:30.021000
# 1155  2013-07-13T12:09:31.188000
# 1156  2013-07-13T11:17:52.308000
#
#                                                 CONTENT  CLASS
# 0     Huh, anyway check out this you[tube] channel: ...      1
# 1      me shaking my sexy ass on my channel enjoy ^_^ ﻿      1
# 2               watch?v=vtaRGgvGtWQ   Check this out .﻿      1
# 3                             Subscribe to my channel ﻿      1
# 4     and u should.d check my channel and tell me wh...      1
# ...                                                 ...    ...
# 1152  **CHECK OUT MY NEW MIXTAPE**** **CHECK OUT MY ...      1
# 1153                                Waka waka she rules      0
# 1154  I love this song for two reasons: 1.it is abou...      0
# 1155                                                wow      0
# 1156                            Shakira u are so wiredo      0
#
# [1157 rows x 5 columns]

# %%
test=pd.read_csv('test.csv')

# %%
test
# Out:
#       ID                                   COMMENT_ID            AUTHOR  \
# 0      0  LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 1      1  LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 2      2  LZQPQhLyRh9-wNRtlZDM90f1k0BrdVdJyN_YsaSwfxc      Jason Haddad
# 3      3        z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k      Bob Kanowski
# 4      4          z13ttt1jcraqexk2o234ghbgzxymz1zzi04              Cony
# ..   ...                                          ...               ...
# 794  794  _2viQ_Qnc6-jk58CPwBnqfbM6oByJH5oPvCtKecLQyo   Shadrach Grentz
# 795  795  _2viQ_Qnc689m-WiwOwvrQU7LvkLAgspnfXL8ovE0ME   TheHotChocolate
# 796  796  _2viQ_Qnc6_1Hq9MGlefkBIszt9rYD3S_CozADvMhQ4     Dinova Sharon
# 797  797  _2viQ_Qnc6-bMSjqyL1NKj57ROicCSJV5SwTrw-RFFA      Katie Mettam
# 798  798  _2viQ_Qnc685RPw1aSa1tfrIuHXRvAQ2rPT9R06KTqA       Latin Bosch
#
#                            DATE  \
# 0           2013-11-07T12:37:15
# 1           2013-11-08T17:34:21
# 2           2013-11-26T02:55:11
# 3           2013-11-28T12:33:27
# 4           2013-11-28T16:01:47
# ..                          ...
# 794  2013-07-14T03:11:20.243000
# 795  2013-07-13T18:26:37.017000
# 796  2013-07-13T14:44:00.700000
# 797  2013-07-13T13:27:39.441000
# 798  2013-07-12T22:33:27.916000
#
#                                                CONTENT
# 0    Hey guys check out my new channel and our firs...
# 1               just for test I have to say murdev.com
# 2    Hey, check out my new website!! This site is a...
# 3    i turned it on mute as soon is i came on i jus...
# 4      You should check my channel for Funny VIDEOS!!﻿
# ..                                                 ...
# 794  Hey Music Fans I really appreciate all of you ...
# 795                           she is sooooo beautiful!
# 796                                  well done shakira
# 797  I love this song because we sing it at Camp al...
# 798                         Shakira is the best dancer
#
# [799 rows x 5 columns]

# %%
test.drop(columns='ID', inplace =True)

# %%
test
# Out:
#                                       COMMENT_ID            AUTHOR  \
# 0    LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 1    LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 2    LZQPQhLyRh9-wNRtlZDM90f1k0BrdVdJyN_YsaSwfxc      Jason Haddad
# 3          z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k      Bob Kanowski
# 4            z13ttt1jcraqexk2o234ghbgzxymz1zzi04              Cony
# ..                                           ...               ...
# 794  _2viQ_Qnc6-jk58CPwBnqfbM6oByJH5oPvCtKecLQyo   Shadrach Grentz
# 795  _2viQ_Qnc689m-WiwOwvrQU7LvkLAgspnfXL8ovE0ME   TheHotChocolate
# 796  _2viQ_Qnc6_1Hq9MGlefkBIszt9rYD3S_CozADvMhQ4     Dinova Sharon
# 797  _2viQ_Qnc6-bMSjqyL1NKj57ROicCSJV5SwTrw-RFFA      Katie Mettam
# 798  _2viQ_Qnc685RPw1aSa1tfrIuHXRvAQ2rPT9R06KTqA       Latin Bosch
#
#                            DATE  \
# 0           2013-11-07T12:37:15
# 1           2013-11-08T17:34:21
# 2           2013-11-26T02:55:11
# 3           2013-11-28T12:33:27
# 4           2013-11-28T16:01:47
# ..                          ...
# 794  2013-07-14T03:11:20.243000
# 795  2013-07-13T18:26:37.017000
# 796  2013-07-13T14:44:00.700000
# 797  2013-07-13T13:27:39.441000
# 798  2013-07-12T22:33:27.916000
#
#                                                CONTENT
# 0    Hey guys check out my new channel and our firs...
# 1               just for test I have to say murdev.com
# 2    Hey, check out my new website!! This site is a...
# 3    i turned it on mute as soon is i came on i jus...
# 4      You should check my channel for Funny VIDEOS!!﻿
# ..                                                 ...
# 794  Hey Music Fans I really appreciate all of you ...
# 795                           she is sooooo beautiful!
# 796                                  well done shakira
# 797  I love this song because we sing it at Camp al...
# 798                         Shakira is the best dancer
#
# [799 rows x 4 columns]

# %%
train.isnull().sum()
# Out:
# COMMENT_ID      0
# AUTHOR          0
# DATE          138
# CONTENT         0
# CLASS           0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# COMMENT_ID      0
# AUTHOR          0
# DATE          107
# CONTENT         0
# dtype: int64

# %%
train.nunique()
# Out:
# COMMENT_ID    1156
# AUTHOR        1094
# DATE          1019
# CONTENT       1057
# CLASS            2
# dtype: int64

# %%
test.nunique()
# Out:
# COMMENT_ID    799
# AUTHOR        760
# DATE          692
# CONTENT       733
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1157 entries, 0 to 1156
# Data columns (total 5 columns):
# COMMENT_ID    1157 non-null object
# AUTHOR        1157 non-null object
# DATE          1019 non-null object
# CONTENT       1157 non-null object
# CLASS         1157 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 45.3+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799 entries, 0 to 798
# Data columns (total 4 columns):
# COMMENT_ID    799 non-null object
# AUTHOR        799 non-null object
# DATE          692 non-null object
# CONTENT       799 non-null object
# dtypes: object(4)
# memory usage: 25.1+ KB

# %%
#for text pre-processing
import re, string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

# %%
x=train['CLASS'].value_counts()
print(x)
sns.barplot(x.index,x)
# Out:
# 1    586
# 0    571
# Name: CLASS, dtype: int64

# %%
# WORD-COUNT
train['word_count'] = train['CONTENT'].apply(lambda x: len(str(x).split()))
print(train[train['CLASS']==1]['word_count'].mean()) #ads tweets
print(train[train['CLASS']==0]['word_count'].mean()) #Non-ads tweets
# Out:
# 22.12627986348123
# 8.84938704028021

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,4))
train_words=train[train['CLASS']==1]['word_count']
ax1.hist(train_words,color='red')
ax1.set_title('Ads tweets')
train_words=train[train['CLASS']==0]['word_count']
ax2.hist(train_words,color='green')
ax2.set_title('Non-Ads tweets')
fig.suptitle('Words per tweet')
plt.show()

# %%
#convert to lowercase, strip and remove punctuations
def preprocess(text):
    text = text.lower() 
    text=text.strip()  
    text=re.compile('<.*?>').sub('', text) 
    text = re.compile('[%s]' % re.escape(string.punctuation)).sub(' ', text)  
    text = re.sub('\s+', ' ', text)  
    text = re.sub(r'\[[0-9]*\]',' ',text) 
    text=re.sub(r'[^\w\s]', '', str(text).lower().strip())
    text = re.sub(r'\d',' ',text) 
    text = re.sub(r'\s+',' ',text) 
    return text

# %%
#STOPWORD REMOVAL
def stopword(string):
    a= [i for i in string.split() if i not in stopwords.words('english')]
    return ' '.join(a)

# %%
#LEMMATIZATION
# Initialize the lemmatizer
wl = WordNetLemmatizer()
 
# This is a helper function to map NTLK position tags
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
# Tokenize the sentence
def lemmatizer(string):
    word_pos_tags = nltk.pos_tag(word_tokenize(string)) # Get position tags
    a=[wl.lemmatize(tag[0], get_wordnet_pos(tag[1])) for idx, tag in enumerate(word_pos_tags)] # Map the position tag and lemmatize the word/token
    return " ".join(a)

# %%
def finalpreprocess(string):
    return lemmatizer(stopword(preprocess(string)))

# %%
train['clean_text'] = train['CONTENT'].apply(lambda x: finalpreprocess(x))

# %%
#nltk.download('averaged_perceptron_tagger')

# %%
train.head(20)
# Out:
#                                      COMMENT_ID                AUTHOR  \
# 0   LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU             Julius NM
# 19  2014-01-20T02:50:44  YouTube/codytolleson for awesome videos I'll s...
#
#     CLASS  word_count                                         clean_text
# 0       1           8             huh anyway check tube channel kobyoshi
# 1       1          11                        shake sexy as channel enjoy
# 2       1           5                          watch v vtarggvgtwq check
# 3       1           5                                  subscribe channel
# 4       1          14                          u check channel tell next
# 5       1          35  start read stop subscribe within one day entir...
# 6       1           1                   http twitter com gbphotographygb
# 7       1           4  please like http premium easypromosapp com voteme
# 8       1          57  hello like game art video scientific experimen...
# 9       0           5                                         check view
# 10      1           6  show auburn pride http www teespring com tiger...
# 11      1           4                                      check channel
# 12      1          45  hey guy im yr old music producer make chiptune...
# 13      0          17         dont even watch anymore come check billion
# 14      1           9                   subscribe free android game apps
# 15      1          14  everyone please come check new song memory mar...
# 16      1           7                                 sub channel reason
# 17      1          17  check dubstep song fireball make fruity loop r...
# 18      0           3                                  billion come soon
# 19      1           8  youtube codytolleson awesome video subscribe back

# %%
from sklearn.model_selection import train_test_split

# %%
# pip install gensim==3.8.1
# Out:
# Collecting gensim==3.8.1
#   Downloading gensim-3.8.1-cp37-cp37m-win_amd64.whl (24.2 MB)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\jaydeep\anaconda3\lib\site-packages (from gensim==3.8.1) (5.1.0)
# Requirement already satisfied: six>=1.5.0 in c:\users\jaydeep\anaconda3\lib\site-packages (from gensim==3.8.1) (1.14.0)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\jaydeep\anaconda3\lib\site-packages (from gensim==3.8.1) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\jaydeep\anaconda3\lib\site-packages (from gensim==3.8.1) (1.18.1)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.0.1
#     Uninstalling gensim-4.0.1:
#       Successfully uninstalled gensim-4.0.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\jaydeep\\anaconda3\\lib\\site-packages\\~ensim\\corpora\\_mmreader.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 21.0.1; however, version 21.1.3 is available.
# You should consider upgrading via the 'C:\Users\Jaydeep\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import gensim
from gensim.models import Word2Vec

# %%
# create Word2vec model
#here words_f should be a list containing words from each document. say 1st row of the list is words from the 1st document/sentence
#length of words_f is number of documents/sentences in your dataset
train['clean_text_tok']=[nltk.word_tokenize(i) for i in train['clean_text']] #convert preprocessed sentence to tokenized sentence
model = Word2Vec(train['clean_text_tok'],min_count=1)  #min_count=1 means word should be present at least across all documents,
#if min_count=2 means if the word is present less than 2 times across all the documents then we shouldn't consider it

# %%
w2v = dict(zip(model.wv.index2word, model.wv.syn0))  #combination of word and its vector
# Out:
# C:\Users\Jaydeep\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   """Entry point for launching an IPython kernel.

# %%
w2v
# Out:
# {'check': array([-7.0018237e-03,  2.0984350e-02, -1.0192093e-02,  4.2670923e-03,
#         -6.2948726e-03,  9.6490895e-03,  5.9474548e-03, -1.5032999e-02,
#         -1.6549043e-02, -2.0847363e-02,  1.4230360e-02, -2.4976362e-03,
#         -5.4444936e-03, -3.2427831e-04,  2.0496001e-02, -3.1238152e-03,
#         -2.0855336e-02,  3.9181164e-03, -2.0500932e-02, -4.5852931e-03,
#         -1.2862929e-02,  3.5752244e-02,  8.3364714e-03, -9.7934157e-03,
#          6.6507247e-04, -5.3541590e-03, -7.5704055e-03,  3.7122965e-03,
#          8.8576982e-03, -1.8232496e-03, -1.7646495e-02,  6.4592669e-03,
#          1.8101943e-03,  2.4311584e-03,  2.8621333e-03,  3.3398324e-03,
#          2.3411685e-03, -9.7343023e-04,  2.3632974e-03, -8.4260112e-04,
#         -6.0405751e-04,  3.3918601e-03, -2.2555448e-03,  7.0302351e-04,
#         -4.3475386e-03,  2.3129035e-03, -3.1100011e-03, -1.5237998e-03,
#          4.7143777e-03,  1.1582291e-03, -3.9530438e-03,  1.1869903e-03],
#        dtype=float32),
#  'evil': array([-1.6930964e-03,  4.6926150e-03,  1.9215816e-03,  4.9696644e-03,
#         -4.1893222e-03, -2.4460102e-03,  4.6006134e-03,  1.8647367e-03,
#          3.5226073e-03,  1.3056701e-03, -2.6864209e-05,  3.5370104e-03,
#          3.5776879e-04, -2.3548547e-03, -2.8071483e-03, -2.4013782e-03,
#         -1.5564080e-03, -3.6337906e-03, -2.9990510e-03,  1.1431248e-03,
#          4.5869346e-03, -3.5438119e-03,  1.0801189e-03, -2.2730832e-03,
#          2.8881843e-03,  2.9637914e-03, -3.9825742e-03, -2.6524989e-03,
#         -1.7275031e-03, -1.7798231e-05,  1.3142657e-03,  4.2318106e-03,
#          2.6250517e-03,  4.3168158e-04,  1.7183404e-03,  7.3836028e-04,
#         -1.4879628e-03, -3.2002111e-03, -2.4025242e-03, -3.1051459e-04,
#         -4.7557927e-03,  2.1679654e-04, -1.3621527e-03, -3.8720639e-03,
#          9.5768555e-05,  4.7781463e-03, -3.0743813e-03, -5.9007842e-04,
#          1.4758861e-03,  3.7069770e-03,  4.4971527e-04, -8.8146235e-06,
#         -3.2333198e-03,  2.9600656e-03, -1.7199090e-03,  5.5130903e-04,
#         -2.7809458e-05,  3.1326406e-03,  1.9312216e-03,  2.6434171e-03,
#         -2.3353670e-03, -7.6911552e-04,  3.2951308e-03,  6.4972503e-04,
#         -2.0690924e-03, -3.8047382e-04, -2.3392655e-03,  1.2987074e-03,
#         -3.7738862e-03, -2.5324775e-03,  2.0589447e-03,  2.4759155e-03,
#          2.9912326e-03, -3.5459214e-04, -2.1167884e-04, -1.8462780e-03,
#          4.0877340e-03, -2.4332171e-03, -3.8411252e-03, -1.9629118e-03,
#         -1.3892206e-03,  1.6705333e-03,  3.2152716e-04, -2.9191924e-03,
#          3.8634578e-03,  3.0853252e-03,  4.7478676e-04, -4.2625051e-03,
#         -4.2682271e-03,  4.4855294e-03, -2.5889205e-03, -2.0636555e-03,
#         -4.4201864e-03, -4.4996217e-03,  7.9034717e-04,  7.6124532e-04,
#         -2.2657581e-04, -1.1374383e-03, -1.9659665e-03,  2.6489000e-03],
#        dtype=float32),
#  ...}

# %%
#for converting sentence to vectors/numbers from word vectors result by Word2Vec
class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        # if a text is empty we should return a vector of zeros
        # with the same dimensionality as all the other vectors
        self.dim = len(next(iter(word2vec.values())))

    def fit(self, X, y):
        return self

    def transform(self, X):
        return np.array([
            np.mean([self.word2vec[w] for w in words if w in self.word2vec]
                    or [np.zeros(self.dim)], axis=0)
            for words in X
        ])

# %%
modelw = MeanEmbeddingVectorizer(w2v)

# %%
#SPLITTING THE TRAINING DATASET INTO TRAIN AND TEST
X_train, X_test, y_train, y_test = train_test_split(train["clean_text"],train["CLASS"],test_size=0.2,shuffle=True)

# %%
X_train.shape,y_train.shape
# Out:
# ((925,), (925,))

# %%
X_test.shape,y_test.shape
# Out:
# ((232,), (232,))

# %%
#Word2Vec
# Word2Vec runs on tokenized sentences
X_train_tok= [nltk.word_tokenize(i) for i in X_train]  
X_test_tok= [nltk.word_tokenize(i) for i in X_test]

# %%
X_train_vectors_w2v = modelw.transform(X_train_tok)

# %%
X_val_vectors_w2v = modelw.transform(X_test_tok)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
#FITTING THE CLASSIFICATION MODEL using Logistic Regression (W2v)
lr_w2v=LogisticRegression(solver = 'liblinear', C=10, penalty = 'l2')
lr_w2v.fit(X_train_vectors_w2v, y_train)  #model
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#Predict y value for test dataset
y_predict = lr_w2v.predict(X_val_vectors_w2v)
y_prob = lr_w2v.predict_proba(X_val_vectors_w2v)[:,1]
print(classification_report(y_test,y_predict))
print('Confusion Matrix:',confusion_matrix(y_test, y_predict))
 
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
print('AUC:', roc_auc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.65      0.66       122
#            1       0.62      0.64      0.63       110
#
#     accuracy                           0.64       232
#    macro avg       0.64      0.64      0.64       232
# weighted avg       0.64      0.64      0.64       232
#
# Confusion Matrix: [[79 43]
#  [40 70]]
# AUC: 0.6773472429210133

# %%
###TFIDF
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(use_idf=True)
X_train_vectors_tfidf = tfidf_vectorizer.fit_transform(X_train) 
X_test_vectors_tfidf = tfidf_vectorizer.transform(X_test)

# %%
#FITTING THE CLASSIFICATION MODEL using Logistic Regression(tf-idf)
lr_tfidf=LogisticRegression(solver = 'liblinear', C=10, penalty = 'l2')
lr_tfidf.fit(X_train_vectors_tfidf, y_train)
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#Predict y value for test dataset
y_predict = lr_tfidf.predict(X_test_vectors_tfidf)
y_prob = lr_tfidf.predict_proba(X_test_vectors_tfidf)[:,1]
print(classification_report(y_test,y_predict))
print('Confusion Matrix:',confusion_matrix(y_test, y_predict))
 
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
print('AUC:', roc_auc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       122
#            1       0.95      0.88      0.92       110
#
#     accuracy                           0.92       232
#    macro avg       0.93      0.92      0.92       232
# weighted avg       0.92      0.92      0.92       232
#
# Confusion Matrix: [[117   5]
#  [ 13  97]]
# AUC: 0.973882265275708

# %%
roc_auc_score(y_test, y_prob)
# Out:
# 0.973882265275708

# %%
##using Naive Bayes

#FITTING THE CLASSIFICATION MODEL using Naive Bayes(tf-idf)
nb_tfidf = MultinomialNB()
nb_tfidf.fit(X_train_vectors_tfidf, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
#Predict y value for test dataset
y_predict = nb_tfidf.predict(X_test_vectors_tfidf)
y_prob = nb_tfidf.predict_proba(X_test_vectors_tfidf)[:,1]
print(classification_report(y_test,y_predict))
print('Confusion Matrix:',confusion_matrix(y_test, y_predict))
 
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
print('AUC:', roc_auc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87       122
#            1       0.83      0.90      0.86       110
#
#     accuracy                           0.87       232
#    macro avg       0.87      0.87      0.87       232
# weighted avg       0.87      0.87      0.87       232
#
# Confusion Matrix: [[102  20]
#  [ 11  99]]
# AUC: 0.9546572280178838

# %%
import xgboost as xgb

# %%
xgb_clf = xgb.XGBClassifier()

# %%
##using xgboost
xgb_clf.fit(X_train_vectors_tfidf, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
##Predicting xgboost
y_predict = xgb_clf.predict(X_test_vectors_tfidf)
y_prob = xgb_clf.predict_proba(X_test_vectors_tfidf)[:,1]
print(classification_report(y_test,y_predict))
print('Confusion Matrix:',confusion_matrix(y_test, y_predict))
 
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
print('AUC:', roc_auc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       122
#            1       0.99      0.85      0.91       110
#
#     accuracy                           0.92       232
#    macro avg       0.93      0.92      0.92       232
# weighted avg       0.93      0.92      0.92       232
#
# Confusion Matrix: [[121   1]
#  [ 17  93]]
# AUC: 0.9592026825633382

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf = RandomForestClassifier()

# %%
rf_clf.fit(X_train_vectors_tfidf, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
##Predicting xgboost
y_predict = rf_clf.predict(X_test_vectors_tfidf)
y_prob = rf_clf.predict_proba(X_test_vectors_tfidf)[:,1]
print(classification_report(y_test,y_predict))
print('Confusion Matrix:',confusion_matrix(y_test, y_predict))
 
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
print('AUC:', roc_auc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       122
#            1       0.96      0.87      0.91       110
#
#     accuracy                           0.92       232
#    macro avg       0.93      0.92      0.92       232
# weighted avg       0.93      0.92      0.92       232
#
# Confusion Matrix: [[118   4]
#  [ 14  96]]
# AUC: 0.9622205663189269

# %%
## Applying on test dataset
test['clean_text'] = test['CONTENT'].apply(lambda x: finalpreprocess(x)) #preprocess the data

# %%
test
# Out:
#       ID                                   COMMENT_ID            AUTHOR  \
# 0      0  LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 1      1  LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 2      2  LZQPQhLyRh9-wNRtlZDM90f1k0BrdVdJyN_YsaSwfxc      Jason Haddad
# 3      3        z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k      Bob Kanowski
# 4      4          z13ttt1jcraqexk2o234ghbgzxymz1zzi04              Cony
# ..   ...                                          ...               ...
# 794  794  _2viQ_Qnc6-jk58CPwBnqfbM6oByJH5oPvCtKecLQyo   Shadrach Grentz
# 795  795  _2viQ_Qnc689m-WiwOwvrQU7LvkLAgspnfXL8ovE0ME   TheHotChocolate
# 796  796  _2viQ_Qnc6_1Hq9MGlefkBIszt9rYD3S_CozADvMhQ4     Dinova Sharon
# 797  797  _2viQ_Qnc6-bMSjqyL1NKj57ROicCSJV5SwTrw-RFFA      Katie Mettam
# 798  798  _2viQ_Qnc685RPw1aSa1tfrIuHXRvAQ2rPT9R06KTqA       Latin Bosch
#
#                            DATE  \
# 0           2013-11-07T12:37:15
# 1           2013-11-08T17:34:21
# 2           2013-11-26T02:55:11
# 3           2013-11-28T12:33:27
# 4           2013-11-28T16:01:47
# ..                          ...
# 794  2013-07-14T03:11:20.243000
# 795  2013-07-13T18:26:37.017000
# 796  2013-07-13T14:44:00.700000
# 797  2013-07-13T13:27:39.441000
# 798  2013-07-12T22:33:27.916000
#
#                                                CONTENT  \
# 0    Hey guys check out my new channel and our firs...
# 1               just for test I have to say murdev.com
# 2    Hey, check out my new website!! This site is a...
# 3    i turned it on mute as soon is i came on i jus...
# 4      You should check my channel for Funny VIDEOS!!﻿
# ..                                                 ...
# 794  Hey Music Fans I really appreciate all of you ...
# 795                           she is sooooo beautiful!
# 796                                  well done shakira
# 797  I love this song because we sing it at Camp al...
# 798                         Shakira is the best dancer
#
#                                             clean_text
# 0    hey guy check new channel first vid u monkey m...
# 1                                  test say murdev com
# 2    hey check new website site kid stuff kidsmedia...
# 3                  turn mute soon come want check view
# 4                            check channel funny video
# ..                                                 ...
# 794  hey music fan really appreciate take time read...
# 795                                   sooooo beautiful
# 796                                    well do shakira
# 797                           love song sing camp time
# 798                                shakira best dancer
#
# [799 rows x 6 columns]

# %%
test_X=test['clean_text']

# %%
test_X_vectors_tfidf = tfidf_vectorizer.transform(test_X)

# %%
y_predict = lr_tfidf.predict(test_X_vectors_tfidf)

# %%
y_prob = rf.predict_proba(test_X_vectors_tfidf)[:,1]

# %%
test['predict_prob']= y_prob
test['target']= y_predict

# %%
test
# Out:
#       ID                                   COMMENT_ID            AUTHOR  \
# 0      0  LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 1      1  LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 2      2  LZQPQhLyRh9-wNRtlZDM90f1k0BrdVdJyN_YsaSwfxc      Jason Haddad
# 3      3        z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k      Bob Kanowski
# 4      4          z13ttt1jcraqexk2o234ghbgzxymz1zzi04              Cony
# ..   ...                                          ...               ...
# 794  794  _2viQ_Qnc6-jk58CPwBnqfbM6oByJH5oPvCtKecLQyo   Shadrach Grentz
# 795  795  _2viQ_Qnc689m-WiwOwvrQU7LvkLAgspnfXL8ovE0ME   TheHotChocolate
# 796  796  _2viQ_Qnc6_1Hq9MGlefkBIszt9rYD3S_CozADvMhQ4     Dinova Sharon
# 797  797  _2viQ_Qnc6-bMSjqyL1NKj57ROicCSJV5SwTrw-RFFA      Katie Mettam
# 798  798  _2viQ_Qnc685RPw1aSa1tfrIuHXRvAQ2rPT9R06KTqA       Latin Bosch
#
#                            DATE  \
# 0           2013-11-07T12:37:15
# 1           2013-11-08T17:34:21
# 2           2013-11-26T02:55:11
# 3           2013-11-28T12:33:27
# 4           2013-11-28T16:01:47
# ..                          ...
# 794  2013-07-14T03:11:20.243000
# 795  2013-07-13T18:26:37.017000
# 796  2013-07-13T14:44:00.700000
# 797  2013-07-13T13:27:39.441000
# 798  2013-07-12T22:33:27.916000
#
#                                                CONTENT  \
# 0    Hey guys check out my new channel and our firs...
# 1               just for test I have to say murdev.com
# 2    Hey, check out my new website!! This site is a...
# 3    i turned it on mute as soon is i came on i jus...
# 4      You should check my channel for Funny VIDEOS!!﻿
# ..                                                 ...
# 794  Hey Music Fans I really appreciate all of you ...
# 795                           she is sooooo beautiful!
# 796                                  well done shakira
# 797  I love this song because we sing it at Camp al...
# 798                         Shakira is the best dancer
#
#                                             clean_text  predict_prob  target
# 0    hey guy check new channel first vid u monkey m...      0.999661       1
# 1                                  test say murdev com      0.916161       1
# 2    hey check new website site kid stuff kidsmedia...      0.995384       1
# 3                  turn mute soon come want check view      0.157204       0
# 4                            check channel funny video      0.991241       1
# ..                                                 ...           ...     ...
# 794  hey music fan really appreciate take time read...      0.980065       1
# 795                                   sooooo beautiful      0.045957       0
# 796                                    well do shakira      0.111541       0
# 797                           love song sing camp time      0.066753       0
# 798                                shakira best dancer      0.038138       0
#
# [799 rows x 8 columns]

# %%
final_sub=test[['ID','target']].reset_index(drop=True)

# %%
final_sub
# Out:
#       ID  target
# 0      0       1
# 1      1       1
# 2      2       1
# 3      3       0
# 4      4       1
# ..   ...     ...
# 794  794       1
# 795  795       0
# 796  796       0
# 797  797       0
# 798  798       0
#
# [799 rows x 2 columns]

# %%
final_sub.rename(columns={'target': 'CLASS'}, inplace =True)

# %%
final_sub
# Out:
#       ID  CLASS
# 0      0      1
# 1      1      1
# 2      2      1
# 3      3      0
# 4      4      1
# ..   ...    ...
# 794  794      1
# 795  795      0
# 796  796      0
# 797  797      0
# 798  798      0
#
# [799 rows x 2 columns]

# %%
final_sub.to_csv('mysubmission.csv', index= False)

# %%
# train

# %%
final_sub
# Out:
#       ID  CLASS
# 0      0      1
# 1      1      1
# 2      2      1
# 3      3      0
# 4      4      1
# ..   ...    ...
# 794  794      1
# 795  795      0
# 796  796      0
# 797  797      0
# 798  798      0
#
# [799 rows x 2 columns]

# %%
y_rf_predict = rf_clf.predict(test_X_vectors_tfidf)

# %%
test['target_rf']= y_rf_predict

# %%
test
# Out:
#       ID                                   COMMENT_ID            AUTHOR  \
# 0      0  LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 1      1  LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 2      2  LZQPQhLyRh9-wNRtlZDM90f1k0BrdVdJyN_YsaSwfxc      Jason Haddad
# 3      3        z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k      Bob Kanowski
# 4      4          z13ttt1jcraqexk2o234ghbgzxymz1zzi04              Cony
# ..   ...                                          ...               ...
# 794  794  _2viQ_Qnc6-jk58CPwBnqfbM6oByJH5oPvCtKecLQyo   Shadrach Grentz
# 795  795  _2viQ_Qnc689m-WiwOwvrQU7LvkLAgspnfXL8ovE0ME   TheHotChocolate
# 796  796  _2viQ_Qnc6_1Hq9MGlefkBIszt9rYD3S_CozADvMhQ4     Dinova Sharon
# 797  797  _2viQ_Qnc6-bMSjqyL1NKj57ROicCSJV5SwTrw-RFFA      Katie Mettam
# 798  798  _2viQ_Qnc685RPw1aSa1tfrIuHXRvAQ2rPT9R06KTqA       Latin Bosch
#
#                            DATE  \
# 0           2013-11-07T12:37:15
# 1           2013-11-08T17:34:21
# 2           2013-11-26T02:55:11
# 3           2013-11-28T12:33:27
# 4           2013-11-28T16:01:47
# ..                          ...
# 794  2013-07-14T03:11:20.243000
# 795  2013-07-13T18:26:37.017000
# 796  2013-07-13T14:44:00.700000
# 797  2013-07-13T13:27:39.441000
# 798  2013-07-12T22:33:27.916000
#
#                                                CONTENT  \
# 0    Hey guys check out my new channel and our firs...
# 1               just for test I have to say murdev.com
# 2    Hey, check out my new website!! This site is a...
# 3    i turned it on mute as soon is i came on i jus...
# 4      You should check my channel for Funny VIDEOS!!﻿
# ..                                                 ...
# 794  Hey Music Fans I really appreciate all of you ...
# 795                           she is sooooo beautiful!
# 796                                  well done shakira
# 797  I love this song because we sing it at Camp al...
# 798                         Shakira is the best dancer
#
#                                             clean_text  predict_prob  target  \
# 0    hey guy check new channel first vid u monkey m...      0.999661       1
# 1                                  test say murdev com      0.916161       1
# 2    hey check new website site kid stuff kidsmedia...      0.995384       1
# 3                  turn mute soon come want check view      0.157204       0
# 4                            check channel funny video      0.991241       1
# ..                                                 ...           ...     ...
# 794  hey music fan really appreciate take time read...      0.980065       1
# 795                                   sooooo beautiful      0.045957       0
# 796                                    well do shakira      0.111541       0
# 797                           love song sing camp time      0.066753       0
# 798                                shakira best dancer      0.038138       0
#
#      target_rf
# 0            1
# 1            1
# 2            1
# 3            0
# 4            1
# ..         ...
# 794          1
# 795          0
# 796          0
# 797          0
# 798          0
#
# [799 rows x 9 columns]

# %%
final_rf=test[['ID','target_rf']].reset_index(drop=True)

# %%
final_rf.rename(columns={'target_rf': 'CLASS'}, inplace =True)

# %%
final_rf.to_csv('mysubmission_2.csv', index= False)

# %%
y_xgb_predict = xgb_clf.predict(test_X_vectors_tfidf)

# %%
test['target_xgb']= y_xgb_predict

# %%
final_xgb=test[['ID','target_xgb']].reset_index(drop=True)
final_xgb.rename(columns={'target_xgb': 'CLASS'}, inplace =True)

# %%
final_xgb.to_csv('mysubmission_3.csv', index=False)

# %%
##SVC
from sklearn import svm

# %%
svc_clf = svm.SVC(kernel='linear', C = 1.0)

# %%
svc_clf.fit(X_train_vectors_tfidf, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
##Predicting xgboost
y_predict = svc_clf.predict(X_test_vectors_tfidf)
# y_prob = svc_clf.predict_proba(X_test_vectors_tfidf)[:,1]
print(classification_report(y_test,y_predict))
print('Confusion Matrix:',confusion_matrix(y_test, y_predict))
 
fpr, tpr, thresholds = roc_curve(y_test, y_predict)
roc_auc = auc(fpr, tpr)
print('AUC:', roc_auc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       122
#            1       0.94      0.89      0.92       110
#
#     accuracy                           0.92       232
#    macro avg       0.92      0.92      0.92       232
# weighted avg       0.92      0.92      0.92       232
#
# Confusion Matrix: [[116   6]
#  [ 12  98]]
# AUC: 0.9208643815201192

# %%
##Decisiontree
from sklearn.tree import DecisionTreeClassifier

# %%
tree_clf = DecisionTreeClassifier(random_state=0)

# %%
tree_clf.fit(X_train_vectors_tfidf, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
##Predicting xgboost
y_predict = tree_clf.predict(X_test_vectors_tfidf)
y_prob = tree_clf.predict_proba(X_test_vectors_tfidf)[:,1]
print(classification_report(y_test,y_predict))
print('Confusion Matrix:',confusion_matrix(y_test, y_predict))
 
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
print('AUC:', roc_auc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91       122
#            1       0.93      0.86      0.90       110
#
#     accuracy                           0.91       232
#    macro avg       0.91      0.90      0.90       232
# weighted avg       0.91      0.91      0.90       232
#
# Confusion Matrix: [[115   7]
#  [ 15  95]]
# AUC: 0.903129657228018

# %%
from sklearn.model_selection import cross_val_score

# %%
cv =cross_val_score(lr_tfidf, X_train_vectors_tfidf, y_train, cv=50)

# %%
cv.min()
# Out:
# 0.7368421052631579
